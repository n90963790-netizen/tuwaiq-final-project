# %% [markdown]
# <a href="https://colab.research.google.com/github/n90963790-netizen/tuwaiq-final-project/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_packages="""pandas
numpy
seaborn
matplotlip"""
with open('requirements.txt','w')as f:
  f.write(python_packages)
  print ('Done')
# Out:
# Done
